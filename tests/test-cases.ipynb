# %% [markdown]
# # Test Notebook for the NHL Linemate Scraper
# ---
# ### Purpose
# The purpose of the ipynb file is to test to ensure that the data created by the NHL Linemate Scraper is accurate. This scraper presents a unique challenge, in that we don't have a data set to directly compare it to, so we have to get creative.
# ### Methods
# We need to do the following to ensure our data is actually correct:
#
# 1. Verify our function to extract the shift data from the html reports works properly
# 2. Verify that our function to add each player on the ice at every second works properly
# 3. Verify that our function that tells us how long each line/pair was on the ice for at 5v5 strength works properly
#
# To reach these conclusions, we must take the following steps:
#
# 1. Compare the player shifts report Data Frame that the scraper is extracting from the html reports to the actual html reports for a handful of games.
#     - Acceptance Criteria -They should match 1:1 and we should confirm that no data is lost from the bs4 scraping function.
# 2. Add up each players All Sit, EV, and PP TOI.
#     - Acceptance Criteria - Eery player's TOI matches on our calculations to the NHL's html report for each game state scenario (with the exception of when a goalie is pulled/too many men).
# 3. Compare the linemate data frame (the one that contains who is on the ice at every second of the game) to the paly-by-play html file and match up game seconds to confirm who was on the ice at each event.
#     - Acceptance Criteria - It should match up in a way that we can index an event to my linemate df, and we should have the same players on ice on our df and the html paly-by-play report
# 4. Manually loop through each game second and check the TOI for the top 10 forward combos and top 10 defensive pairs according to the 5v5 reports
#     - Acceptance Criteria - The TOIs of these lines and pairs should match the reports when we manually look up how long they were on the ice
#
# If the cases above are valid, then our data will be correct.
#
# I will be testing 3 games - A game where a goalie gets pulled, a "normal" game, and a game with a too many men penalty. I chose these test cases to show that the scraper can handle any kind of game.

# %% [markdown]
# # Prepare Notebook

# %%
# Import
import pandas as pd

# %%
# Functions I'll use throughout
# Function to extract a players TOI at any strength:
def extract_toi(player,team,strength):
    if strength=="all":
        df = linemate_data
    else:
        df = linemate_data[linemate_data['strength_cat']==strength]
    df = df[(df['{}_player_1_name'.format(team)]==player)|(df['{}_player_2_name'.format(team)]==player)|(df['{}_player_3_name'.format(team)]==player)|(df['{}_player_4_name'.format(team)]==player)|(df['{}_player_5_name'.format(team)]==player)|(df['{}_player_6_name'.format(team)]==player)]
    toi = len(df)/60
    return toi

# Function to calcualte each lines TOI
def calculate_forward_line_toi(p1,p2,p3,team):
    df = linemate_data[linemate_data['strength']=="5v5"]
    df = df[((df['{}_player_1_name'.format(team)]==p1)|(df['{}_player_2_name'.format(team)]==p1)|(df['{}_player_3_name'.format(team)]==p1)|(df['{}_player_4_name'.format(team)]==p1)|(df['{}_player_5_name'.format(team)]==p1)|(df['{}_player_6_name'.format(team)]==p1))&
            ((df['{}_player_1_name'.format(team)]==p2)|(df['{}_player_2_name'.format(team)]==p2)|(df['{}_player_3_name'.format(team)]==p2)|(df['{}_player_4_name'.format(team)]==p2)|(df['{}_player_5_name'.format(team)]==p2)|(df['{}_player_6_name'.format(team)]==p2))&
            ((df['{}_player_1_name'.format(team)]==p3)|(df['{}_player_2_name'.format(team)]==p3)|(df['{}_player_3_name'.format(team)]==p3)|(df['{}_player_4_name'.format(team)]==p3)|(df['{}_player_5_name'.format(team)]==p3)|(df['{}_player_6_name'.format(team)]==p3))]
    toi = len(df)/60
    return toi

# Function to calcualte each pairs TOI
def calculate_defender_pair_toi(p1,p2,team):
    df = linemate_data[linemate_data['strength']=="5v5"]
    df = df[((df['{}_player_1_name'.format(team)]==p1)|(df['{}_player_2_name'.format(team)]==p1)|(df['{}_player_3_name'.format(team)]==p1)|(df['{}_player_4_name'.format(team)]==p1)|(df['{}_player_5_name'.format(team)]==p1)|(df['{}_player_6_name'.format(team)]==p1))&
            ((df['{}_player_1_name'.format(team)]==p2)|(df['{}_player_2_name'.format(team)]==p2)|(df['{}_player_3_name'.format(team)]==p2)|(df['{}_player_4_name'.format(team)]==p2)|(df['{}_player_5_name'.format(team)]==p2)|(df['{}_player_6_name'.format(team)]==p2))]
    toi = len(df)/60
    return toi

# %% [markdown]
# # Test Game 1 - 2023020017 - A normal game
# What we expect - This game features no goalie pulls or too many men calls, so we should see exact matches for all cases

# %% [markdown]
# ### Test Case 1 - Compare Extracted Shift Data to html Shift Data
# Shift for game 2023020017 can be found at https://www.nhl.com/scores/htmlreports/20232024/TV020017.HTM and https://www.nhl.com/scores/htmlreports/20232024/TH020017.HTM

# %%
# Read in my extracted shifts from this game. This is the df of extracted shifts from the bs4 function. It's what is used to build the by second df
extracted_shift_data = pd.read_csv("data/shift-data-for-testing-2023020017.csv")
extracted_shift_data
# Out:
#      Unnamed: 0  shift_number  period shift_start_time shift_end_time  \
# 0             0             1       1             1:28           2:18
# 1             1             2       1             4:33           5:26
# 2             2             3       1             7:26           8:16
# 3             3             4       1             9:28           9:57
# 4             4             5       1            12:54          13:34
# ..          ...           ...     ...              ...            ...
# 797         401            18       3            12:44          13:55
# 798         402            19       3            15:09          16:10
# 799         403            20       3            17:06          17:34
# 800         404            21       4             1:04           1:50
# 801         405            22       4             3:33           3:57
#
#     duration Event  player_number last_name first_name  \
# 0      00:50   NaN              2     SMITH    BRENDAN
# 1      00:53   NaN              2     SMITH    BRENDAN
# 2      00:50   NaN              2     SMITH    BRENDAN
# 3      00:29     P              2     SMITH    BRENDAN
# 4      00:40   NaN              2     SMITH    BRENDAN
# ..       ...   ...            ...       ...        ...
# 797    01:11     G             92    COOLEY      LOGAN
# 798    01:01   NaN             92    COOLEY      LOGAN
# 799    00:28   NaN             92    COOLEY      LOGAN
# 800    00:46   NaN             92    COOLEY      LOGAN
# 801    00:24     P             92    COOLEY      LOGAN
#
#      shift_start_time_seconds  shift_end_time_seconds  duration_seconds team  \
# 0                          88                     138                50  NJD
# 1                         273                     326                53  NJD
# 2                         446                     496                50  NJD
# 3                         568                     597                29  NJD
# 4                         774                     814                40  NJD
# ..                        ...                     ...               ...  ...
# 797                      3164                    3235                71  ARI
# 798                      3309                    3370                61  ARI
# 799                      3426                    3454                28  ARI
# 800                      3664                    3710                46  ARI
# 801                      3813                    3837                24  ARI
#
#      playerId positionCode firstName.default lastName.default position  \
# 0     8474090            D           Brendan            Smith        D
# 1     8474090            D           Brendan            Smith        D
# 2     8474090            D           Brendan            Smith        D
# 3     8474090            D           Brendan            Smith        D
# 4     8474090            D           Brendan            Smith        D
# ..        ...          ...               ...              ...      ...
# 797   8483431            C             Logan           Cooley        F
# 798   8483431            C             Logan           Cooley        F
# 799   8483431            C             Logan           Cooley        F
# 800   8483431            C             Logan           Cooley        F
# 801   8483431            C             Logan           Cooley        F
#
#          full_name
# 0    Brendan Smith
# 1    Brendan Smith
# 2    Brendan Smith
# 3    Brendan Smith
# 4    Brendan Smith
# ..             ...
# 797   Logan Cooley
# 798   Logan Cooley
# 799   Logan Cooley
# 800   Logan Cooley
# 801   Logan Cooley
#
# [802 rows x 20 columns]

# %% [markdown]
# #### Test Case 1A - Compare Shift Counts for Every Player in Game 2023020017

# %%
# This is the number of shifts for each player. Go throguh each html doc and compare
extracted_shift_data.groupby('full_name').count()[['shift_number']]
# Out:
#                     shift_number
# full_name
# Akira Schmid                   4
# Alex Kerfoot                  18
# Alexander Holtz               14
# Barrett Hayton                28
# Brendan Smith                 22
# Clayton Keller                26
# Dawson Mercer                 20
# Dougie Hamilton               29
# Erik Haula                    20
# J.J. Moser                    24
# Jack Hughes                   26
# Jack McBain                   17
# Jason Zucker                  18
# Jesper Bratt                  22
# John Marino                   28
# Jonas Siegenthaler            26
# Josh Brown                    18
# Juuso Valimaki                24
# Karel Vejmelka                 4
# Kevin Bahl                    28
# Lawson Crouse                 23
# Liam O'Brien                  15
# Logan Cooley                  22
# Luke Hughes                   25
# Matias Maccelli               22
# Matt Dumba                    29
# Michael Carcone               14
# Michael McLeod                14
# Nathan Bastian                14
# Nick Bjugstad                 23
# Nick Schmaltz                 26
# Nico Hischier                 28
# Ondrej Palat                  18
# Sean Durzi                    27
# Timo Meier                    22
# Tomas Nosek                   16
# Travis Dermott                28
# Tyler Toffoli                 20

# %% [markdown]
# #### Test Case 1B - Compare shifts match for a few players on the HTML reports

# %%
# John Marino
extracted_shift_data[extracted_shift_data['full_name']=="John Marino"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#     shift_number  period shift_start_time shift_end_time duration Event  \
# 22             1       1             0:00           0:26    00:26   NaN
# 23             2       1             2:18           3:09    00:51   NaN
# 24             3       1             6:22           7:28    01:06     P
# 25             4       1             8:15           8:41    00:26   NaN
# 26             5       1             9:54           9:57    00:03     P
# 27             6       1            11:53          12:54    01:01   NaN
# 28             7       1            15:26          16:25    00:59   NaN
# 29             8       1            17:21          18:15    00:54   NaN
# 30             9       2             0:00           0:27    00:27   NaN
# 31            10       2             3:00           4:23    01:23     G
# 32            11       2             6:08           7:51    01:43     P
# 33            12       2             9:51           9:55    00:04   NaN
# 34            13       2            10:08          10:46    00:38     P
# 35            14       2            12:46          12:53    00:07   NaN
# 36            15       2            14:37          15:02    00:25   NaN
# 37            16       2            16:02          16:52    00:50   NaN
# 38            17       2            19:44          20:00    00:16   NaN
# 39            18       3             0:00           0:34    00:34   NaN
# 40            19       3             2:28           3:22    00:54   NaN
# 41            20       3             5:36           6:23    00:47     P
# 42            21       3             7:00           8:17    01:17   NaN
# 43            22       3            10:07          10:49    00:42   NaN
# 44            23       3            12:44          13:55    01:11     G
# 45            24       3            15:35          16:43    01:08   NaN
# 46            25       3            17:37          18:49    01:12   NaN
# 47            26       3            19:38          20:00    00:22   NaN
# 48            27       4             2:05           3:17    01:12   NaN
# 49            28       4             3:57           5:00    01:03   NaN
#
#       full_name
# 22  John Marino
# 23  John Marino
# 24  John Marino
# 25  John Marino
# 26  John Marino
# 27  John Marino
# 28  John Marino
# 29  John Marino
# 30  John Marino
# 31  John Marino
# 32  John Marino
# 33  John Marino
# 34  John Marino
# 35  John Marino
# 36  John Marino
# 37  John Marino
# 38  John Marino
# 39  John Marino
# 40  John Marino
# 41  John Marino
# 42  John Marino
# 43  John Marino
# 44  John Marino
# 45  John Marino
# 46  John Marino
# 47  John Marino
# 48  John Marino
# 49  John Marino

# %%
# Clayton Keller
extracted_shift_data[extracted_shift_data['full_name']=="Clayton Keller"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 464             1       1             0:00           0:44    00:44   NaN
# 465             2       1             2:49           3:33    00:44   NaN
# 466             3       1             6:13           7:50    01:37    GP
# 467             4       1             9:17           9:57    00:40     P
# 468             5       1            12:15          12:59    00:44   NaN
# 469             6       1            15:22          16:07    00:45   NaN
# 470             7       1            17:21          18:10    00:49   NaN
# 471             8       2             0:00           0:29    00:29   NaN
# 472             9       2             3:00           4:23    01:23     G
# 473            10       2             6:08           6:40    00:32   NaN
# 474            11       2             7:51           8:09    00:18     G
# 475            12       2             8:55          10:29    01:34   NaN
# 476            13       2            12:29          12:44    00:15   NaN
# 477            14       2            15:50          16:48    00:58   NaN
# 478            15       3             0:00           0:31    00:31   NaN
# 479            16       3             2:26           3:18    00:52   NaN
# 480            17       3             5:43           6:12    00:29   NaN
# 481            18       3             6:59           8:21    01:22   NaN
# 482            19       3            10:07          10:46    00:39   NaN
# 483            20       3            12:44          13:55    01:11     G
# 484            21       3            16:10          16:43    00:33   NaN
# 485            22       3            17:34          18:04    00:30   NaN
# 486            23       3            19:37          20:00    00:23   NaN
# 487            24       4             0:00           1:00    01:00   NaN
# 488            25       4             2:43           3:33    00:50   NaN
# 489            26       4             3:57           5:00    01:03   NaN
#
#           full_name
# 464  Clayton Keller
# 465  Clayton Keller
# 466  Clayton Keller
# 467  Clayton Keller
# 468  Clayton Keller
# 469  Clayton Keller
# 470  Clayton Keller
# 471  Clayton Keller
# 472  Clayton Keller
# 473  Clayton Keller
# 474  Clayton Keller
# 475  Clayton Keller
# 476  Clayton Keller
# 477  Clayton Keller
# 478  Clayton Keller
# 479  Clayton Keller
# 480  Clayton Keller
# 481  Clayton Keller
# 482  Clayton Keller
# 483  Clayton Keller
# 484  Clayton Keller
# 485  Clayton Keller
# 486  Clayton Keller
# 487  Clayton Keller
# 488  Clayton Keller
# 489  Clayton Keller

# %%
# Karel Vejmelka
extracted_shift_data[extracted_shift_data['full_name']=="Karel Vejmelka"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 752             1       1             0:00          20:00    20:00    GP
# 753             2       2             0:00          20:00    20:00    GP
# 754             3       3             0:00          20:00    20:00    GP
# 755             4       4             0:00           5:00    05:00     P
#
#           full_name
# 752  Karel Vejmelka
# 753  Karel Vejmelka
# 754  Karel Vejmelka
# 755  Karel Vejmelka

# %% [markdown]
# Shift counts and shift times/durations match for each tested case.
#
# Test Case 1 Passed ✅

# %% [markdown]
# ### Test Case 2 - Compare Each Players All Sit, EV, PP, SH TOI
# Shifts for game 2023020017 can be found at https://www.nhl.com/scores/htmlreports/20232024/TV020017.HTM and https://www.nhl.com/scores/htmlreports/20232024/TH020017.HTM

# %%
# Read in linemate_data 
linemate_data = pd.read_csv("data/linemate-data-for-testing-2023020017.csv")
linemate_data
# Out:
#       Unnamed: 0 home_player_1_name  home_player_1_id home_player_1_position  \
# 0              0        John Marino           8478507                      D
# 1              1        John Marino           8478507                      D
# 2              2        John Marino           8478507                      D
# 3              3        John Marino           8478507                      D
# 4              4        John Marino           8478507                      D
# ...          ...                ...               ...                    ...
# 3895        3895        John Marino           8478507                      D
# 3896        3896        John Marino           8478507                      D
# 3897        3897        John Marino           8478507                      D
# 3898        3898        John Marino           8478507                      D
# 3899        3899        John Marino           8478507                      D
#
#      home_player_2_name  home_player_2_id home_player_2_position  \
# 0            Kevin Bahl           8480860                      D
# 1            Kevin Bahl           8480860                      D
# 2            Kevin Bahl           8480860                      D
# 3            Kevin Bahl           8480860                      D
# 4            Kevin Bahl           8480860                      D
# ...                 ...               ...                    ...
# 3895         Kevin Bahl           8480860                      D
# 3896         Kevin Bahl           8480860                      D
# 3897         Kevin Bahl           8480860                      D
# 3898         Kevin Bahl           8480860                      D
# 3899         Kevin Bahl           8480860                      D
#
#      home_player_3_name  home_player_3_id home_player_3_position  ...  \
# 0         Nico Hischier           8480002                      F  ...
# 1         Nico Hischier           8480002                      F  ...
# 2         Nico Hischier           8480002                      F  ...
# 3         Nico Hischier           8480002                      F  ...
# 4         Nico Hischier           8480002                      F  ...
# ...                 ...               ...                    ...  ...
# 3895      Nico Hischier           8480002                      F  ...
# 3896      Nico Hischier           8480002                      F  ...
# 3897      Nico Hischier           8480002                      F  ...
# 3898      Nico Hischier           8480002                      F  ...
# 3899      Nico Hischier           8480002                      F  ...
#
#      home_skaters_on_ice  away_skaters_on_ice strength    strength_cat  \
# 0                      5                    5      5v5            even
# 1                      5                    5      5v5            even
# 2                      5                    5      5v5            even
# 3                      5                    5      5v5            even
# 4                      5                    5      5v5            even
# ...                  ...                  ...      ...             ...
# 3895                   3                    4      3v4  away_advantage
# 3896                   3                    4      3v4  away_advantage
# 3897                   3                    4      3v4  away_advantage
# 3898                   3                    4      3v4  away_advantage
# 3899                   3                    4      3v4  away_advantage
#
#       home_team away_team   game_date  game_season     game_id       game_type
# 0           NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 1           NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 2           NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 3           NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 4           NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# ...         ...       ...         ...          ...         ...             ...
# 3895        NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 3896        NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 3897        NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 3898        NJD       ARI  2023-10-13     20232024  2023020017  regular-season
# 3899        NJD       ARI  2023-10-13     20232024  2023020017  regular-season
#
# [3900 rows x 49 columns]

# %%
# Matias Maccelli
all_toi = extract_toi("Matias Maccelli","away","all")
ev_toi = extract_toi("Matias Maccelli","away","even")
pp_toi = extract_toi("Matias Maccelli","away","away_advantage")
sh_toi = extract_toi("Matias Maccelli","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 16.633333333333333 EV: 13.833333333333334 PP: 2.7333333333333334 SH: 0.06666666666666667

# %%
# Nick Bjugstad
all_toi = extract_toi("Nick Bjugstad","away","all")
ev_toi = extract_toi("Nick Bjugstad","away","even")
pp_toi = extract_toi("Nick Bjugstad","away","away_advantage")
sh_toi = extract_toi("Nick Bjugstad","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 15.95 EV: 12.116666666666667 PP: 2.566666666666667 SH: 1.2666666666666666

# %%
# Brendan Smith
all_toi = extract_toi("Brendan Smith","home","all")
ev_toi = extract_toi("Brendan Smith","home","even")
pp_toi = extract_toi("Brendan Smith","home","home_advantage")
sh_toi = extract_toi("Brendan Smith","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 15.466666666666667 EV: 12.516666666666667 PP: 0.0 SH: 2.95

# %%
# Dougie Hamilton
all_toi = extract_toi("Dougie Hamilton","home","all")
ev_toi = extract_toi("Dougie Hamilton","home","even")
pp_toi = extract_toi("Dougie Hamilton","home","home_advantage")
sh_toi = extract_toi("Dougie Hamilton","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 22.166666666666668 EV: 19.8 PP: 2.3666666666666667 SH: 0.0

# %%
# Akiria Schmid
all_toi = extract_toi("Akira Schmid","home","all")
ev_toi = extract_toi("Akira Schmid","home","even")
pp_toi = extract_toi("Akira Schmid","home","home_advantage")
sh_toi = extract_toi("Akira Schmid","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 65.0 EV: 49.016666666666666 PP: 6.216666666666667 SH: 9.766666666666667

# %% [markdown]
# Player TOI's match exact for test cases
#
# Test Case 2 Passed ✅

# %% [markdown]
# ### Test Case 3 - Compare html PBP On-Ice for Events to linemate_data Data Frame
# Should show the same players on ice at each even. PBP data can be found at https://www.nhl.com/scores/htmlreports/20232024/PL020017.HTM

# %%
# Goal scored at 6:22 of the 1st period
linemate_data[linemate_data['second']==382][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#     home_player_1_name  home_player_2_name home_player_3_name  \
# 381    Dougie Hamilton  Jonas Siegenthaler    Alexander Holtz
#
#     home_player_4_name home_player_5_name home_player_6_name  \
# 381       Ondrej Palat         Erik Haula       Akira Schmid
#
#     away_player_1_name away_player_2_name away_player_3_name  \
# 381         Matt Dumba         J.J. Moser      Nick Schmaltz
#
#     away_player_4_name away_player_5_name away_player_6_name
# 381     Clayton Keller     Barrett Hayton     Karel Vejmelka

# %%
# Random shot at 1:21 of the 2nd
linemate_data[linemate_data['second']==1281][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#      home_player_1_name home_player_2_name home_player_3_name  \
# 1280      Brendan Smith        Luke Hughes       Jesper Bratt
#
#      home_player_4_name home_player_5_name home_player_6_name  \
# 1280      Tyler Toffoli        Jack Hughes       Akira Schmid
#
#      away_player_1_name away_player_2_name away_player_3_name  \
# 1280         Josh Brown     Juuso Valimaki    Matias Maccelli
#
#      away_player_4_name away_player_5_name away_player_6_name
# 1280      Lawson Crouse       Logan Cooley     Karel Vejmelka

# %%
# Random shot at 2:17 of OT
linemate_data[linemate_data['second']==3738][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#      home_player_1_name home_player_2_name home_player_3_name  \
# 3737        John Marino       Jesper Bratt        Jack Hughes
#
#      home_player_4_name home_player_5_name home_player_6_name  \
# 3737       Akira Schmid                NaN                NaN
#
#      away_player_1_name away_player_2_name away_player_3_name  \
# 3737         Sean Durzi       Jason Zucker     Barrett Hayton
#
#      away_player_4_name away_player_5_name away_player_6_name
# 3737     Karel Vejmelka                NaN                NaN

# %% [markdown]
# On-Ice players match exactly for test cases
#
# Test Case 3 Passed ✅

# %% [markdown]
# ### Test Case 4 - Ensure Forward Line and Defensive Pair 5v5 TOI is Correct
# Manually loop through to make sure the function to calculate forward and defensemen line toi works

# %%
# Read in forward 5v5 report DF
forward_5v5 = pd.read_csv("data/5v5-forward-report-for-testing-2023020017.csv").head(10)
forward_5v5
# Out:
#    Unnamed: 0          forward_line_id   forward_1_name  forward_1_id  \
# 0           0  8475726-8479407-8481559     Jesper Bratt       8479407
# 1           1  8477951-8479343-8480849    Nick Schmaltz       8477951
# 2           2  8475760-8478474-8481711    Nick Bjugstad       8475760
# 3           3  8478414-8480002-8482110    Nico Hischier       8480002
# 4           4  8475722-8477021-8483431     Alex Kerfoot       8477021
# 5           5  8475287-8476292-8482125  Alexander Holtz       8482125
# 6           6  8477070-8479619-8480855      Jack McBain       8480855
# 7           7  8477931-8479414-8479415   Nathan Bastian       8479414
# 8           8  8478414-8481559-8482110       Timo Meier       8478414
# 9           9  8475287-8476292-8479414   Nathan Bastian       8479414
#
#     forward_2_name  forward_2_id   forward_3_name  forward_3_id  toi_secs  \
# 0    Tyler Toffoli       8475726      Jack Hughes     8481559.0       622
# 1   Clayton Keller       8479343   Barrett Hayton     8480849.0       584
# 2  Matias Maccelli       8481711    Lawson Crouse     8478474.0       573
# 3       Timo Meier       8478414    Dawson Mercer     8482110.0       533
# 4     Jason Zucker       8475722     Logan Cooley     8483431.0       500
# 5     Ondrej Palat       8476292       Erik Haula     8475287.0       376
# 6     Liam O'Brien       8477070  Michael Carcone     8479619.0       354
# 7   Michael McLeod       8479415      Tomas Nosek     8477931.0       337
# 8      Jack Hughes       8481559    Dawson Mercer     8482110.0       125
# 9     Ondrej Palat       8476292       Erik Haula     8475287.0        74
#
#     toi_mins team        date    season     game_id       game_type
# 0  10.366667  NJD  2023-10-13  20232024  2023020017  regular-season
# 1   9.733333  ARI  2023-10-13  20232024  2023020017  regular-season
# 2   9.550000  ARI  2023-10-13  20232024  2023020017  regular-season
# 3   8.883333  NJD  2023-10-13  20232024  2023020017  regular-season
# 4   8.333333  ARI  2023-10-13  20232024  2023020017  regular-season
# 5   6.266667  NJD  2023-10-13  20232024  2023020017  regular-season
# 6   5.900000  ARI  2023-10-13  20232024  2023020017  regular-season
# 7   5.616667  NJD  2023-10-13  20232024  2023020017  regular-season
# 8   2.083333  NJD  2023-10-13  20232024  2023020017  regular-season
# 9   1.233333  NJD  2023-10-13  20232024  2023020017  regular-season

# %%
# For the top 5 most common lines in the game, lookup how maany 5v5 mins they played together through the linemate_data df. If they  match exactly, our function to build forward line toi reports works perfectly
for line in forward_5v5['forward_line_id'].tolist():
    p1 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_1_name']
    p2 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_2_name']
    p3 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_3_name']
    print(p1,p2,p3)
    if forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['team']=="NJD":
        print("Manual Calculation TOI:",calculate_forward_line_toi(p1,p2,p3,'home')," - Linemate Report TOI:",forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['toi_mins'])
    else:
        print("Manual Calculation TOI:",calculate_forward_line_toi(p1,p2,p3,'away')," - Linemate Report TOI:",forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['toi_mins'])
    print()
# Looks good. Lets do defenders now
# Out:
# Jesper Bratt Tyler Toffoli Jack Hughes
# Manual Calculation TOI: 10.366666666666667  - Linemate Report TOI: 10.366666666666667
#
# Nick Schmaltz Clayton Keller Barrett Hayton
# Manual Calculation TOI: 9.733333333333333  - Linemate Report TOI: 9.733333333333333
#
# Nick Bjugstad Matias Maccelli Lawson Crouse
# Manual Calculation TOI: 9.55  - Linemate Report TOI: 9.55
#
# Nico Hischier Timo Meier Dawson Mercer
# Manual Calculation TOI: 8.883333333333333  - Linemate Report TOI: 8.883333333333333
#
# Alex Kerfoot Jason Zucker Logan Cooley
# Manual Calculation TOI: 8.333333333333334  - Linemate Report TOI: 8.333333333333334
#
# Alexander Holtz Ondrej Palat Erik Haula
# Manual Calculation TOI: 6.266666666666667  - Linemate Report TOI: 6.266666666666667
#
# Jack McBain Liam O'Brien Michael Carcone
# Manual Calculation TOI: 5.9  - Linemate Report TOI: 5.9
#
# Nathan Bastian Michael McLeod Tomas Nosek
# Manual Calculation TOI: 5.616666666666666  - Linemate Report TOI: 5.616666666666666
#
# Timo Meier Jack Hughes Dawson Mercer
# Manual Calculation TOI: 2.0833333333333335  - Linemate Report TOI: 2.083333333333333
#
# Nathan Bastian Ondrej Palat Erik Haula
# Manual Calculation TOI: 1.2333333333333334  - Linemate Report TOI: 1.2333333333333334

# %%
# Read in defender report
defender_5v5 = pd.read_csv("data/5v5-defender-report-for-testing-2023020017.csv").head(10)
defender_5v5
# Out:
#    Unnamed: 0 defensemen_pair_id defensemen_1_name  defensemen_1_id  \
# 0           0    8476462-8478399   Dougie Hamilton          8476462
# 1           1    8478507-8480860       John Marino          8478507
# 2           2    8474090-8482684     Brendan Smith          8474090
# 3           3    8476856-8482655        Matt Dumba          8476856
# 4           4    8478408-8479976    Juuso Valimaki          8479976
# 5           5    8477384-8480434        Josh Brown          8477384
# 6           6    8476856-8478408        Matt Dumba          8476856
# 7           7    8479976-8480434    Juuso Valimaki          8479976
# 8           8    8476462-8480860   Dougie Hamilton          8476462
# 9           9    8477384-8482655        Josh Brown          8477384
#
#     defensemen_2_name  defensemen_2_id  toi_secs   toi_mins team        date  \
# 0  Jonas Siegenthaler          8478399       841  14.016667  NJD  2023-10-13
# 1          Kevin Bahl          8480860       717  11.950000  NJD  2023-10-13
# 2         Luke Hughes          8482684       685  11.416667  NJD  2023-10-13
# 3          J.J. Moser          8482655       643  10.716667  ARI  2023-10-13
# 4      Travis Dermott          8478408       591   9.850000  ARI  2023-10-13
# 5          Sean Durzi          8480434       466   7.766667  ARI  2023-10-13
# 6      Travis Dermott          8478408       340   5.666667  ARI  2023-10-13
# 7          Sean Durzi          8480434       201   3.350000  ARI  2023-10-13
# 8          Kevin Bahl          8480860       101   1.683333  NJD  2023-10-13
# 9          J.J. Moser          8482655        93   1.550000  ARI  2023-10-13
#
#      season     game_id       game_type
# 0  20232024  2023020017  regular-season
# 1  20232024  2023020017  regular-season
# 2  20232024  2023020017  regular-season
# 3  20232024  2023020017  regular-season
# 4  20232024  2023020017  regular-season
# 5  20232024  2023020017  regular-season
# 6  20232024  2023020017  regular-season
# 7  20232024  2023020017  regular-season
# 8  20232024  2023020017  regular-season
# 9  20232024  2023020017  regular-season

# %%
# For the top 5 most common lines in the game, lookup how maany 5v5 mins they played together through the linemate_data df. If they  match exactly, our function to build forward line toi reports works perfectly
for pair in defender_5v5['defensemen_pair_id'].tolist():
    p1 = defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['defensemen_1_name']
    p2 = defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['defensemen_2_name']
    print(p1,p2)
    if defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['team']=="NJD":
        print("Manual Calculation TOI:",calculate_defender_pair_toi(p1,p2,'home')," - Linemate Report TOI:",defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['toi_mins'])
    else:
        print("Manual Calculation TOI:",calculate_defender_pair_toi(p1,p2,'away')," - Linemate Report TOI:",defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['toi_mins'])
    print()
# Out:
# Dougie Hamilton Jonas Siegenthaler
# Manual Calculation TOI: 14.016666666666667  - Linemate Report TOI: 14.016666666666667
#
# John Marino Kevin Bahl
# Manual Calculation TOI: 11.95  - Linemate Report TOI: 11.95
#
# Brendan Smith Luke Hughes
# Manual Calculation TOI: 11.416666666666666  - Linemate Report TOI: 11.416666666666666
#
# Matt Dumba J.J. Moser
# Manual Calculation TOI: 10.716666666666667  - Linemate Report TOI: 10.716666666666669
#
# Juuso Valimaki Travis Dermott
# Manual Calculation TOI: 9.85  - Linemate Report TOI: 9.85
#
# Josh Brown Sean Durzi
# Manual Calculation TOI: 7.766666666666667  - Linemate Report TOI: 7.766666666666667
#
# Matt Dumba Travis Dermott
# Manual Calculation TOI: 5.666666666666667  - Linemate Report TOI: 5.666666666666667
#
# Juuso Valimaki Sean Durzi
# Manual Calculation TOI: 3.35  - Linemate Report TOI: 3.35
#
# Dougie Hamilton Kevin Bahl
# Manual Calculation TOI: 1.6833333333333333  - Linemate Report TOI: 1.6833333333333331
#
# Josh Brown J.J. Moser
# Manual Calculation TOI: 1.55  - Linemate Report TOI: 1.55

# %% [markdown]
# 5v5 TOI's match perfectly
#
# Test Case 4 Passed ✅

# %% [markdown]
# #### Game 2023020017 Passed ✅

# %% [markdown]
# # Test Game 2 - 2023020337 - A Game Where a Goalie Gets Pulled
# What we expect - A slight difference in a few player TOI's from my data to the html shift data totals. From my understanding, the NHL counts power paly time rather than man advantage time. This scraper instead does man advantage time (and the other way around of course for man disadvantge/short handed)

# %% [markdown]
# ### Test Case 1 - Compare Extracted Shift Data to html Shift Data
# Shift for game 2023020337 can be found at https://www.nhl.com/scores/htmlreports/20232024/TV020337.HTM and https://www.nhl.com/scores/htmlreports/20232024/TH020337.HTM

# %%
# Read in my extracted shifts from this game. This is the df of extracted shifts from the bs4 function. It's what is used to build the by second df
extracted_shift_data = pd.read_csv("data/shift-data-for-testing-2023020337.csv")
extracted_shift_data
# Out:
#      Unnamed: 0  shift_number  period shift_start_time shift_end_time  \
# 0             0             1       1             1:35           2:14
# 1             1             2       1             4:55           5:36
# 2             2             3       1             8:59           9:56
# 3             3             4       1            13:35          14:26
# 4             4             5       1            17:00          18:05
# ..          ...           ...     ...              ...            ...
# 645         321            13       3             3:56           4:13
# 646         322            14       3             6:57           7:53
# 647         323            15       3            12:47          14:01
# 648         324            16       3            16:44          17:42
# 649         325            17       3            19:03          20:00
#
#     duration Event  player_number  last_name first_name  \
# 0      00:39   NaN              4  SILLINGER       COLE
# 1      00:41   NaN              4  SILLINGER       COLE
# 2      00:57   NaN              4  SILLINGER       COLE
# 3      00:51   NaN              4  SILLINGER       COLE
# 4      01:05   NaN              4  SILLINGER       COLE
# ..       ...   ...            ...        ...        ...
# 645    00:17   NaN             91    MONAHAN       SEAN
# 646    00:56   NaN             91    MONAHAN       SEAN
# 647    01:14   NaN             91    MONAHAN       SEAN
# 648    00:58     G             91    MONAHAN       SEAN
# 649    00:57   NaN             91    MONAHAN       SEAN
#
#      shift_start_time_seconds  shift_end_time_seconds  duration_seconds team  \
# 0                          95                     134                39  CBJ
# 1                         295                     336                41  CBJ
# 2                         539                     596                57  CBJ
# 3                         815                     866                51  CBJ
# 4                        1020                    1085                65  CBJ
# ..                        ...                     ...               ...  ...
# 645                      2636                    2653                17  MTL
# 646                      2817                    2873                56  MTL
# 647                      3167                    3241                74  MTL
# 648                      3404                    3462                58  MTL
# 649                      3543                    3600                57  MTL
#
#      playerId positionCode firstName.default lastName.default position  \
# 0     8482705            C              Cole        Sillinger        F
# 1     8482705            C              Cole        Sillinger        F
# 2     8482705            C              Cole        Sillinger        F
# 3     8482705            C              Cole        Sillinger        F
# 4     8482705            C              Cole        Sillinger        F
# ..        ...          ...               ...              ...      ...
# 645   8477497            C              Sean          Monahan        F
# 646   8477497            C              Sean          Monahan        F
# 647   8477497            C              Sean          Monahan        F
# 648   8477497            C              Sean          Monahan        F
# 649   8477497            C              Sean          Monahan        F
#
#           full_name
# 0    Cole Sillinger
# 1    Cole Sillinger
# 2    Cole Sillinger
# 3    Cole Sillinger
# 4    Cole Sillinger
# ..              ...
# 645    Sean Monahan
# 646    Sean Monahan
# 647    Sean Monahan
# 648    Sean Monahan
# 649    Sean Monahan
#
# [650 rows x 20 columns]

# %% [markdown]
# #### Test Case 1A - Compare Shift Counts for Every Player in Game 2023020017

# %%
# This is the number of shifts for each player. Go throguh each html doc and compare
extracted_shift_data.groupby('full_name').count()[['shift_number']]
# Out:
#                      shift_number
# full_name
# Adam Boqvist                   20
# Adam Fantilli                  15
# Alex Newhook                   18
# Alexandre Texier               14
# Boone Jenner                   18
# Brendan Gallagher              17
# Christian Dvorak               17
# Cole Caufield                  15
# Cole Sillinger                 19
# David Jiricek                  18
# Dmitri Voronkov                18
# Elvis Merzlikins                4
# Eric Robinson                  17
# Erik Gudbranson                18
# Gustav Lindström               24
# Ivan Provorov                  19
# Jake Bean                      18
# Jake Evans                     18
# Jayden Struble                 16
# Jesse Ylönen                   10
# Joel Armia                     19
# Johnathan Kovacevic            17
# Johnny Gaudreau                19
# Josh Anderson                  17
# Juraj Slafkovsky               15
# Justin Barron                  24
# Justin Danforth                17
# Kaiden Guhle                   25
# Kirill Marchenko               17
# Mike Matheson                  23
# Nick Suzuki                    19
# Patrik Laine                   15
# Sam Montembeault                3
# Sean Kuraly                    18
# Sean Monahan                   17
# Tanner Pearson                 12
# Yegor Chinakhov                19
# Zach Werenski                  21

# %% [markdown]
# #### Test Case 1B - Compare shifts match for a few players on the HTML reports

# %%
# Cole Sillinger
extracted_shift_data[extracted_shift_data['full_name']=="Cole Sillinger"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#     shift_number  period shift_start_time shift_end_time duration Event  \
# 0              1       1             1:35           2:14    00:39   NaN
# 1              2       1             4:55           5:36    00:41   NaN
# 2              3       1             8:59           9:56    00:57   NaN
# 3              4       1            13:35          14:26    00:51   NaN
# 4              5       1            17:00          18:05    01:05   NaN
# 5              6       2             0:00           1:23    01:23   NaN
# 6              7       2             4:02           4:08    00:06   NaN
# 7              8       2             4:49           5:52    01:03   NaN
# 8              9       2             9:47          10:40    00:53   NaN
# 9             10       2            12:09          12:53    00:44   NaN
# 10            11       2            15:01          15:55    00:54   NaN
# 11            12       2            18:32          19:13    00:41   NaN
# 12            13       3             2:00           2:46    00:46   NaN
# 13            14       3             3:56           4:59    01:03   NaN
# 14            15       3             7:40           8:07    00:27   NaN
# 15            16       3            11:56          12:08    00:12   NaN
# 16            17       3            12:56          13:51    00:55   NaN
# 17            18       3            17:03          17:47    00:44   NaN
# 18            19       3            19:03          19:41    00:38   NaN
#
#          full_name
# 0   Cole Sillinger
# 1   Cole Sillinger
# 2   Cole Sillinger
# 3   Cole Sillinger
# 4   Cole Sillinger
# 5   Cole Sillinger
# 6   Cole Sillinger
# 7   Cole Sillinger
# 8   Cole Sillinger
# 9   Cole Sillinger
# 10  Cole Sillinger
# 11  Cole Sillinger
# 12  Cole Sillinger
# 13  Cole Sillinger
# 14  Cole Sillinger
# 15  Cole Sillinger
# 16  Cole Sillinger
# 17  Cole Sillinger
# 18  Cole Sillinger

# %%
# Yegor Chinakhov
extracted_shift_data[extracted_shift_data['full_name']=="Yegor Chinakhov"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 284             1       1             1:37           2:14    00:37   NaN
# 285             2       1             4:54           5:33    00:39   NaN
# 286             3       1             8:30           9:39    01:09   NaN
# 287             4       1            13:44          14:24    00:40   NaN
# 288             5       1            16:54          17:59    01:05   NaN
# 289             6       2             0:00           1:25    01:25   NaN
# 290             7       2             4:55           5:54    00:59   NaN
# 291             8       2             9:16          10:13    00:57     G
# 292             9       2            12:09          12:53    00:44   NaN
# 293            10       2            15:00          15:57    00:57   NaN
# 294            11       2            18:32          19:10    00:38   NaN
# 295            12       3             2:04           2:48    00:44   NaN
# 296            13       3             3:56           5:01    01:05   NaN
# 297            14       3             7:52           8:07    00:15   NaN
# 298            15       3             9:59          10:43    00:44   NaN
# 299            16       3            11:53          12:08    00:15   NaN
# 300            17       3            12:51          13:43    00:52   NaN
# 301            18       3            17:03          17:43    00:40   NaN
# 302            19       3            19:03          19:42    00:39   NaN
#
#            full_name
# 284  Yegor Chinakhov
# 285  Yegor Chinakhov
# 286  Yegor Chinakhov
# 287  Yegor Chinakhov
# 288  Yegor Chinakhov
# 289  Yegor Chinakhov
# 290  Yegor Chinakhov
# 291  Yegor Chinakhov
# 292  Yegor Chinakhov
# 293  Yegor Chinakhov
# 294  Yegor Chinakhov
# 295  Yegor Chinakhov
# 296  Yegor Chinakhov
# 297  Yegor Chinakhov
# 298  Yegor Chinakhov
# 299  Yegor Chinakhov
# 300  Yegor Chinakhov
# 301  Yegor Chinakhov
# 302  Yegor Chinakhov

# %%
# Sam Montembeault
extracted_shift_data[extracted_shift_data['full_name']=="Sam Montembeault"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 531             1       1             0:00          20:00    20:00   NaN
# 532             2       2             0:00          20:00    20:00    GP
# 533             3       3             0:00          20:00    20:00    GP
#
#             full_name
# 531  Sam Montembeault
# 532  Sam Montembeault
# 533  Sam Montembeault

# %% [markdown]
# Shift counts and shift times/durations match for each tested case.
#
# Test Case 1 Passed ✅

# %% [markdown]
# ### Test Case 2 - Compare Each Players All Sit, EV, PP, SH TOI
# Shifts for game 2023020337 can be found at https://www.nhl.com/scores/htmlreports/20232024/TV020337.HTM and https://www.nhl.com/scores/htmlreports/20232024/TH020337.HTM

# %%
# Read in linemate_data 
linemate_data = pd.read_csv("data/linemate-data-for-testing-2023020337.csv")
linemate_data
# Out:
#       Unnamed: 0 home_player_1_name  home_player_1_id home_player_1_position  \
# 0              0      Zach Werenski           8478460                      D
# 1              1      Zach Werenski           8478460                      D
# 2              2      Zach Werenski           8478460                      D
# 3              3      Zach Werenski           8478460                      D
# 4              4      Zach Werenski           8478460                      D
# ...          ...                ...               ...                    ...
# 3595        3595          Jake Bean           8479402                      D
# 3596        3596          Jake Bean           8479402                      D
# 3597        3597          Jake Bean           8479402                      D
# 3598        3598          Jake Bean           8479402                      D
# 3599        3599          Jake Bean           8479402                      D
#
#      home_player_2_name  home_player_2_id home_player_2_position  \
# 0          Adam Boqvist           8480871                      D
# 1          Adam Boqvist           8480871                      D
# 2          Adam Boqvist           8480871                      D
# 3          Adam Boqvist           8480871                      D
# 4          Adam Boqvist           8480871                      D
# ...                 ...               ...                    ...
# 3595       Adam Boqvist           8480871                      D
# 3596       Adam Boqvist           8480871                      D
# 3597       Adam Boqvist           8480871                      D
# 3598       Adam Boqvist           8480871                      D
# 3599       Adam Boqvist           8480871                      D
#
#      home_player_3_name  home_player_3_id home_player_3_position  ...  \
# 0       Johnny Gaudreau           8476346                      F  ...
# 1       Johnny Gaudreau           8476346                      F  ...
# 2       Johnny Gaudreau           8476346                      F  ...
# 3       Johnny Gaudreau           8476346                      F  ...
# 4       Johnny Gaudreau           8476346                      F  ...
# ...                 ...               ...                    ...  ...
# 3595        Sean Kuraly           8476374                      F  ...
# 3596        Sean Kuraly           8476374                      F  ...
# 3597        Sean Kuraly           8476374                      F  ...
# 3598        Sean Kuraly           8476374                      F  ...
# 3599        Sean Kuraly           8476374                      F  ...
#
#      home_skaters_on_ice  away_skaters_on_ice strength strength_cat  \
# 0                      5                    5      5v5         even
# 1                      5                    5      5v5         even
# 2                      5                    5      5v5         even
# 3                      5                    5      5v5         even
# 4                      5                    5      5v5         even
# ...                  ...                  ...      ...          ...
# 3595                   5                    5      5v5         even
# 3596                   5                    5      5v5         even
# 3597                   5                    5      5v5         even
# 3598                   5                    5      5v5         even
# 3599                   5                    5      5v5         even
#
#       home_team away_team   game_date  game_season     game_id       game_type
# 0           CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 1           CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 2           CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 3           CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 4           CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# ...         ...       ...         ...          ...         ...             ...
# 3595        CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 3596        CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 3597        CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 3598        CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
# 3599        CBJ       MTL  2023-11-29     20232024  2023020337  regular-season
#
# [3600 rows x 49 columns]

# %%
# Nick Suzuki
all_toi = extract_toi("Nick Suzuki","away","all")
ev_toi = extract_toi("Nick Suzuki","away","even")
pp_toi = extract_toi("Nick Suzuki","away","away_advantage")
sh_toi = extract_toi("Nick Suzuki","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
'''
This is a test case I wanted to bring up. 
If you compare to the html shifts, we see that Fantilli is crtedited with less EV TOI and more PP TOI form the scraper compared to the html shift report
The html shift report does not count when a goalie is pulled as an advtange/disadvanage like the scraper does.
If we look at the html play py play report, we can see that at the end of the game, CBJ pulled their goalie. Suzuki was on the ice during this time, as we can see from a shot taken at 18:44 in the 3rd period on the html pbp reprot.
If we look into the linemate_data df, we can confirm this is true as well.
The html pbp shows this as an EV shot, which technially it's not as CBJ has a skater advantage

I will keep this as it is because again, this is technially not even strength play, in my opinion. I would hear people out for changing this, but I think this is correct.
'''
# Out:
# All: 16.45 EV: 15.533333333333333 PP: 0.0 SH: 0.9166666666666666
# "\nThis is a test case I wanted to bring up. \nIf you compare to the html shifts, we see that Fantilli is crtedited with less EV TOI and more PP TOI form the scraper compared to the html shift report\nThe html shift report does not count when a goalie is pulled as an advtange/disadvanage like the scraper does.\nIf we look at the html play py play report, we can see that at the end of the game, CBJ pulled their goalie. Suzuki was on the ice during this time, as we can see from a shot taken at 18:44 in the 3rd.\nThe html pbp shows this as an EV shot, which technially it's not as CBJ has a skater advantage\n\nI will keep this as it is because again, this is technially not even strength play, in my opinion. I would hear people out for changing this, but I think this is correct.\n"

# %%
# Josh Anderson
all_toi = extract_toi("Josh Anderson","away","all")
ev_toi = extract_toi("Josh Anderson","away","even")
pp_toi = extract_toi("Josh Anderson","away","away_advantage")
sh_toi = extract_toi("Josh Anderson","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 16.216666666666665 EV: 16.216666666666665 PP: 0.0 SH: 0.0

# %%
# Eric Robinson
all_toi = extract_toi("Eric Robinson","home","all")
ev_toi = extract_toi("Eric Robinson","home","even")
pp_toi = extract_toi("Eric Robinson","home","home_advantage")
sh_toi = extract_toi("Eric Robinson","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 13.166666666666666 EV: 13.166666666666666 PP: 0.0 SH: 0.0

# %%
# Adam Fantilli
all_toi = extract_toi("Adam Fantilli","home","all")
ev_toi = extract_toi("Adam Fantilli","home","even")
pp_toi = extract_toi("Adam Fantilli","home","home_advantage")
sh_toi = extract_toi("Adam Fantilli","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
'''
Same case as Suzuki
'''
# Out:
# All: 12.5 EV: 11.116666666666667 PP: 1.3833333333333333 SH: 0.0
# '\nSame case as Suzuki\n'

# %%
# Elvis Merzlinkis
all_toi = extract_toi("Elvis Merzlikins","home","all")
ev_toi = extract_toi("Elvis Merzlikins","home","even")
pp_toi = extract_toi("Elvis Merzlikins","home","home_advantage")
sh_toi = extract_toi("Elvis Merzlikins","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 58.93333333333333 EV: 56.93333333333333 PP: 2.0 SH: 0.0

# %% [markdown]
# Player TOI's and the time differences match when they are expected to
#
# Test Case 2 Passed ✅

# %% [markdown]
# ### Test Case 3 - Compare html PBP On-Ice for Events to linemate_data Data Frame
# Should show the same players on ice at each even. PBP data can be found at https://www.nhl.com/scores/htmlreports/20232024/PL020337.HTM

# %%
# Hit at 3 minutes of the 1st period
linemate_data[linemate_data['second']==180][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#     home_player_1_name home_player_2_name home_player_3_name  \
# 179      Zach Werenski       Adam Boqvist        Sean Kuraly
#
#     home_player_4_name home_player_5_name home_player_6_name  \
# 179    Justin Danforth      Eric Robinson   Elvis Merzlikins
#
#     away_player_1_name away_player_2_name away_player_3_name  \
# 179      Mike Matheson       Kaiden Guhle       Jesse Ylönen
#
#     away_player_4_name away_player_5_name away_player_6_name
# 179     Tanner Pearson         Jake Evans   Sam Montembeault

# %%
# Shot at 2:44 of the 2nd period
linemate_data[linemate_data['second']==1364][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#      home_player_1_name home_player_2_name home_player_3_name  \
# 1363      Ivan Provorov      David Jiricek        Sean Kuraly
#
#      home_player_4_name home_player_5_name home_player_6_name  \
# 1363    Justin Danforth      Eric Robinson   Elvis Merzlikins
#
#        away_player_1_name away_player_2_name away_player_3_name  \
# 1363  Johnathan Kovacevic     Jayden Struble   Juraj Slafkovsky
#
#      away_player_4_name away_player_5_name away_player_6_name
# 1363      Cole Caufield   Christian Dvorak   Sam Montembeault

# %%
# Shot at 18:44 of the 3rd period
linemate_data[linemate_data['second']==3524][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#      home_player_1_name home_player_2_name home_player_3_name  \
# 3523      Zach Werenski      Adam Fantilli    Johnny Gaudreau
#
#      home_player_4_name home_player_5_name home_player_6_name  \
# 3523       Patrik Laine       Boone Jenner   Kirill Marchenko
#
#      away_player_1_name away_player_2_name away_player_3_name  \
# 3523       Kaiden Guhle      Justin Barron        Nick Suzuki
#
#      away_player_4_name away_player_5_name away_player_6_name
# 3523   Christian Dvorak         Joel Armia   Sam Montembeault

# %% [markdown]
# ### Test Case 4 - Ensure Forward Line and Defensive Pair 5v5 TOI is Correct
# Manually loop through to make sure the function to calculate forward and defensemen line toi works

# %%
# Read in forward 5v5 report DF
forward_5v5 = pd.read_csv("data/5v5-forward-report-for-testing-2023020337.csv").head(10)
forward_5v5
# Out:
#    Unnamed: 0          forward_line_id     forward_1_name  forward_1_id  \
# 0           0  8476346-8476432-8480893    Johnny Gaudreau       8476346
# 1           1  8476374-8479941-8480762        Sean Kuraly       8476374
# 2           2  8475848-8480018-8481618  Brendan Gallagher       8475848
# 3           3  8477989-8481540-8483515   Juraj Slafkovsky       8483515
# 4           4  8481716-8482475-8482705     Cole Sillinger       8482705
# 5           5  8476469-8476981-8477497      Josh Anderson       8476981
# 6           6  8479339-8480074-8484166      Adam Fantilli       8484166
# 7           7  8476871-8478133-8481058       Jesse Ylönen       8481058
# 8           8  8476981-8477497-8478133      Josh Anderson       8476981
# 9           9  8476346-8476374-8480893        Sean Kuraly       8476374
#
#     forward_2_name  forward_2_id    forward_3_name  forward_3_id  toi_secs  \
# 0     Boone Jenner       8476432  Kirill Marchenko       8480893       831
# 1  Justin Danforth       8479941     Eric Robinson       8480762       747
# 2      Nick Suzuki       8480018      Alex Newhook       8481618       738
# 3    Cole Caufield       8481540  Christian Dvorak       8477989       710
# 4  Dmitri Voronkov       8481716   Yegor Chinakhov       8482475       679
# 5       Joel Armia       8476469      Sean Monahan       8477497       647
# 6     Patrik Laine       8479339  Alexandre Texier       8480074       464
# 7   Tanner Pearson       8476871        Jake Evans       8478133       457
# 8       Jake Evans       8478133      Sean Monahan       8477497       149
# 9  Johnny Gaudreau       8476346  Kirill Marchenko       8480893        71
#
#     toi_mins team        date    season     game_id       game_type
# 0  13.850000  CBJ  2023-11-29  20232024  2023020337  regular-season
# 1  12.450000  CBJ  2023-11-29  20232024  2023020337  regular-season
# 2  12.300000  MTL  2023-11-29  20232024  2023020337  regular-season
# 3  11.833333  MTL  2023-11-29  20232024  2023020337  regular-season
# 4  11.316667  CBJ  2023-11-29  20232024  2023020337  regular-season
# 5  10.783333  MTL  2023-11-29  20232024  2023020337  regular-season
# 6   7.733333  CBJ  2023-11-29  20232024  2023020337  regular-season
# 7   7.616667  MTL  2023-11-29  20232024  2023020337  regular-season
# 8   2.483333  MTL  2023-11-29  20232024  2023020337  regular-season
# 9   1.183333  CBJ  2023-11-29  20232024  2023020337  regular-season

# %%
# For the top 5 most common lines in the game, lookup how maany 5v5 mins they played together through the linemate_data df. If they  match exactly, our function to build forward line toi reports works perfectly
for line in forward_5v5['forward_line_id'].tolist():
    p1 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_1_name']
    p2 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_2_name']
    p3 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_3_name']
    print(p1,p2,p3)
    if forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['team']=="CBJ":
        print("Manual Calculation TOI:",calculate_forward_line_toi(p1,p2,p3,'home')," - Linemate Report TOI:",forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['toi_mins'])
    else:
        print("Manual Calculation TOI:",calculate_forward_line_toi(p1,p2,p3,'away')," - Linemate Report TOI:",forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['toi_mins'])
    print()
# Looks good
# Out:
# Johnny Gaudreau Boone Jenner Kirill Marchenko
# Manual Calculation TOI: 13.85  - Linemate Report TOI: 13.85
#
# Sean Kuraly Justin Danforth Eric Robinson
# Manual Calculation TOI: 12.45  - Linemate Report TOI: 12.45
#
# Brendan Gallagher Nick Suzuki Alex Newhook
# Manual Calculation TOI: 12.3  - Linemate Report TOI: 12.3
#
# Juraj Slafkovsky Cole Caufield Christian Dvorak
# Manual Calculation TOI: 11.833333333333334  - Linemate Report TOI: 11.833333333333334
#
# Cole Sillinger Dmitri Voronkov Yegor Chinakhov
# Manual Calculation TOI: 11.316666666666666  - Linemate Report TOI: 11.316666666666666
#
# Josh Anderson Joel Armia Sean Monahan
# Manual Calculation TOI: 10.783333333333333  - Linemate Report TOI: 10.783333333333331
#
# Adam Fantilli Patrik Laine Alexandre Texier
# Manual Calculation TOI: 7.733333333333333  - Linemate Report TOI: 7.733333333333333
#
# Jesse Ylönen Tanner Pearson Jake Evans
# Manual Calculation TOI: 7.616666666666666  - Linemate Report TOI: 7.616666666666666
#
# Josh Anderson Jake Evans Sean Monahan
# Manual Calculation TOI: 2.4833333333333334  - Linemate Report TOI: 2.4833333333333334
#
# Sean Kuraly Johnny Gaudreau Kirill Marchenko
# Manual Calculation TOI: 1.1833333333333333  - Linemate Report TOI: 1.1833333333333331

# %%
# Read in defender report
defender_5v5 = pd.read_csv("data/5v5-defender-report-for-testing-2023020337.csv").head(10)
defender_5v5
# Out:
#    Unnamed: 0 defensemen_pair_id    defensemen_1_name  defensemen_1_id  \
# 0           0    8482087-8482111         Kaiden Guhle          8482087
# 1           1    8478460-8480871        Zach Werenski          8478460
# 2           2    8475790-8479402            Jake Bean          8479402
# 3           3    8476875-8480184        Mike Matheson          8476875
# 4           4    8478500-8483460        Ivan Provorov          8478500
# 5           5    8480192-8481593  Johnathan Kovacevic          8480192
# 6           6    8476875-8481593        Mike Matheson          8476875
# 7           7    8475790-8478500        Ivan Provorov          8478500
# 8           8    8475790-8478460        Zach Werenski          8478460
# 9           9    8476875-8480192        Mike Matheson          8476875
#
#      defensemen_2_name  defensemen_2_id  toi_secs   toi_mins team        date  \
# 0        Justin Barron          8482111      1125  18.750000  MTL  2023-11-29
# 1         Adam Boqvist          8480871      1000  16.666667  CBJ  2023-11-29
# 2      Erik Gudbranson          8475790       947  15.783333  CBJ  2023-11-29
# 3     Gustav Lindström          8480184       936  15.600000  MTL  2023-11-29
# 4        David Jiricek          8483460       918  15.300000  CBJ  2023-11-29
# 5       Jayden Struble          8481593       694  11.566667  MTL  2023-11-29
# 6       Jayden Struble          8481593       109   1.816667  MTL  2023-11-29
# 7      Erik Gudbranson          8475790       108   1.800000  CBJ  2023-11-29
# 8      Erik Gudbranson          8475790       108   1.800000  CBJ  2023-11-29
# 9  Johnathan Kovacevic          8480192        92   1.533333  MTL  2023-11-29
#
#      season     game_id       game_type
# 0  20232024  2023020337  regular-season
# 1  20232024  2023020337  regular-season
# 2  20232024  2023020337  regular-season
# 3  20232024  2023020337  regular-season
# 4  20232024  2023020337  regular-season
# 5  20232024  2023020337  regular-season
# 6  20232024  2023020337  regular-season
# 7  20232024  2023020337  regular-season
# 8  20232024  2023020337  regular-season
# 9  20232024  2023020337  regular-season

# %%
# For the top 5 most common lines in the game, lookup how maany 5v5 mins they played together through the linemate_data df. If they  match exactly, our function to build forward line toi reports works perfectly
for pair in defender_5v5['defensemen_pair_id'].tolist():
    p1 = defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['defensemen_1_name']
    p2 = defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['defensemen_2_name']
    print(p1,p2)
    if defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['team']=="CBJ":
        print("Manual Calculation TOI:",calculate_defender_pair_toi(p1,p2,'home')," - Linemate Report TOI:",defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['toi_mins'])
    else:
        print("Manual Calculation TOI:",calculate_defender_pair_toi(p1,p2,'away')," - Linemate Report TOI:",defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['toi_mins'])
    print()
# Out:
# Kaiden Guhle Justin Barron
# Manual Calculation TOI: 18.75  - Linemate Report TOI: 18.75
#
# Zach Werenski Adam Boqvist
# Manual Calculation TOI: 16.666666666666668  - Linemate Report TOI: 16.666666666666668
#
# Jake Bean Erik Gudbranson
# Manual Calculation TOI: 15.783333333333333  - Linemate Report TOI: 15.783333333333331
#
# Mike Matheson Gustav Lindström
# Manual Calculation TOI: 15.6  - Linemate Report TOI: 15.6
#
# Ivan Provorov David Jiricek
# Manual Calculation TOI: 15.3  - Linemate Report TOI: 15.3
#
# Johnathan Kovacevic Jayden Struble
# Manual Calculation TOI: 11.566666666666666  - Linemate Report TOI: 11.566666666666666
#
# Mike Matheson Jayden Struble
# Manual Calculation TOI: 1.8166666666666667  - Linemate Report TOI: 1.8166666666666669
#
# Ivan Provorov Erik Gudbranson
# Manual Calculation TOI: 1.8  - Linemate Report TOI: 1.8
#
# Zach Werenski Erik Gudbranson
# Manual Calculation TOI: 1.8  - Linemate Report TOI: 1.8
#
# Mike Matheson Johnathan Kovacevic
# Manual Calculation TOI: 1.5333333333333334  - Linemate Report TOI: 1.5333333333333334

# %% [markdown]
# 5v5 TOI's match perfectly
#
# Test Case 4 Passed ✅

# %% [markdown]
# #### Game 2023020337 Passed ✅

# %% [markdown]
# # Test Game 3 - 2023020028 - A Game With a Too Many Men Penalty
# What we expect - Since this is another case that's a little odd and we will encounter, I figured including this in the testing book made sense. I expect the same thing as a goalie pull. there will be a small TOI discrepancy between the html shifts file and what the scraper says

# %% [markdown]
# ### Test Case 1 - Compare Extracted Shift Data to html Shift Data
# Shift for game 2023020028 can be found at https://www.nhl.com/scores/htmlreports/20232024/TV020028.HTM and https://www.nhl.com/scores/htmlreports/20232024/TH020028.HTM

# %%
# Read in my extracted shifts from this game. This is the df of extracted shifts from the bs4 function. It's what is used to build the by second df
extracted_shift_data = pd.read_csv("data/shift-data-for-testing-2023020028.csv")
extracted_shift_data
# Out:
#      Unnamed: 0  shift_number  period shift_start_time shift_end_time  \
# 0             0             1       1             0:00           0:34
# 1             1             2       1             2:14           2:57
# 2             2             3       1             3:27           4:17
# 3             3             4       1             6:24           6:55
# 4             4             5       1             9:18          10:07
# ..          ...           ...     ...              ...            ...
# 763         393            16       3            13:06          13:38
# 764         394            17       3            14:36          15:35
# 765         395            18       3            18:03          18:39
# 766         396            19       4             0:55           2:00
# 767         397            20       4             4:21           5:00
#
#     duration Event  player_number   last_name first_name  \
# 0      00:34   NaN              4       LEDDY       NICK
# 1      00:43   NaN              4       LEDDY       NICK
# 2      00:50   NaN              4       LEDDY       NICK
# 3      00:31     P              4       LEDDY       NICK
# 4      00:49   NaN              4       LEDDY       NICK
# ..       ...   ...            ...         ...        ...
# 763    00:32   NaN             95  BURAKOVSKY      ANDRE
# 764    00:59   NaN             95  BURAKOVSKY      ANDRE
# 765    00:36   NaN             95  BURAKOVSKY      ANDRE
# 766    01:05   NaN             95  BURAKOVSKY      ANDRE
# 767    00:39   NaN             95  BURAKOVSKY      ANDRE
#
#      shift_start_time_seconds  shift_end_time_seconds  duration_seconds team  \
# 0                           0                      34                34  STL
# 1                         134                     177                43  STL
# 2                         207                     257                50  STL
# 3                         384                     415                31  STL
# 4                         558                     607                49  STL
# ..                        ...                     ...               ...  ...
# 763                      3186                    3218                32  SEA
# 764                      3276                    3335                59  SEA
# 765                      3483                    3519                36  SEA
# 766                      3655                    3720                65  SEA
# 767                      3861                    3900                39  SEA
#
#      playerId positionCode firstName.default lastName.default position  \
# 0     8475181            D              Nick            Leddy        D
# 1     8475181            D              Nick            Leddy        D
# 2     8475181            D              Nick            Leddy        D
# 3     8475181            D              Nick            Leddy        D
# 4     8475181            D              Nick            Leddy        D
# ..        ...          ...               ...              ...      ...
# 763   8477444            L             Andre       Burakovsky        F
# 764   8477444            L             Andre       Burakovsky        F
# 765   8477444            L             Andre       Burakovsky        F
# 766   8477444            L             Andre       Burakovsky        F
# 767   8477444            L             Andre       Burakovsky        F
#
#             full_name
# 0          Nick Leddy
# 1          Nick Leddy
# 2          Nick Leddy
# 3          Nick Leddy
# 4          Nick Leddy
# ..                ...
# 763  Andre Burakovsky
# 764  Andre Burakovsky
# 765  Andre Burakovsky
# 766  Andre Burakovsky
# 767  Andre Burakovsky
#
# [768 rows x 20 columns]

# %% [markdown]
# #### Test Case 1A - Compare Shift Counts for Every Player in Game 2023020028

# %%
# This is the number of shifts for each player. Go throguh each html doc and compare
extracted_shift_data.groupby('full_name').count()[['shift_number']]
# Out:
#                           shift_number
# full_name
# Adam Larsson                        30
# Alex Wennberg                       25
# Alexey Toropchenko                  19
# Andre Burakovsky                    20
# Brandon Saad                        23
# Brayden Schenn                      20
# Brian Dumoulin                      23
# Colton Parayko                      30
# Eeli Tolvanen                       16
# Jaden Schwartz                      22
# Jake Neighbours                     15
# Jakub Vrana                         16
# Jamie Oleksiak                      28
# Jared McCann                        25
# Joey Daccord                         4
# Jordan Binnington                    4
# Jordan Eberle                       24
# Jordan Kyrou                        23
# Justin Faulk                        30
# Justin Schultz                      21
# Kailer Yamamoto                     14
# Kasperi Kapanen                     21
# Kevin Hayes                         20
# Marco Scandella                     15
# Matty Beniers                       24
# Nick Leddy                          26
# Oliver Bjorkstrand                  18
# Oskar Sundqvist                     16
# Pavel Buchnevich                     7
# Pierre-Edouard Bellemare            19
# Robert Thomas                       24
# Sammy Blais                         16
# Torey Krug                          29
# Tye Kartye                          11
# Tyler Tucker                        16
# Vince Dunn                          29
# Will Borgen                         25
# Yanni Gourde                        20

# %% [markdown]
# #### Test Case 1B - Compare shifts match for a few players on the HTML reports

# %%
# Torey Krug
extracted_shift_data[extracted_shift_data['full_name']=="Torey Krug"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 207             1       1             0:34           1:19    00:45   NaN
# 208             2       1             2:57           3:27    00:30   NaN
# 209             3       1             5:02           6:23    01:21   NaN
# 210             4       1             6:55           8:17    01:22   NaN
# 211             5       1            10:59          11:47    00:48   NaN
# 212             6       1            12:36          13:06    00:30   NaN
# 213             7       1            14:52          15:56    01:04   NaN
# 214             8       1            16:28          17:24    00:56   NaN
# 215             9       1            19:16          19:40    00:24   NaN
# 216            10       2             0:40           1:20    00:40   NaN
# 217            11       2             3:15           3:53    00:38   NaN
# 218            12       2             4:58           5:36    00:38   NaN
# 219            13       2             7:04           7:46    00:42   NaN
# 220            14       2             9:00          10:27    01:27   NaN
# 221            15       2            11:18          12:09    00:51   NaN
# 222            16       2            14:10          15:04    00:54   NaN
# 223            17       2            16:14          17:23    01:09   NaN
# 224            18       2            18:56          20:00    01:04   NaN
# 225            19       3             0:58           1:32    00:34   NaN
# 226            20       3             4:00           5:09    01:09   NaN
# 227            21       3             7:52           8:22    00:30   NaN
# 228            22       3             9:27          10:10    00:43   NaN
# 229            23       3            12:12          12:25    00:13   NaN
# 230            24       3            13:15          13:38    00:23   NaN
# 231            25       3            14:30          15:19    00:49   NaN
# 232            26       3            16:32          17:20    00:48   NaN
# 233            27       3            18:08          18:57    00:49   NaN
# 234            28       3            19:25          20:00    00:35   NaN
# 235            29       4             3:52           5:00    01:08   NaN
#
#       full_name
# 207  Torey Krug
# 208  Torey Krug
# 209  Torey Krug
# 210  Torey Krug
# 211  Torey Krug
# 212  Torey Krug
# 213  Torey Krug
# 214  Torey Krug
# 215  Torey Krug
# 216  Torey Krug
# 217  Torey Krug
# 218  Torey Krug
# 219  Torey Krug
# 220  Torey Krug
# 221  Torey Krug
# 222  Torey Krug
# 223  Torey Krug
# 224  Torey Krug
# 225  Torey Krug
# 226  Torey Krug
# 227  Torey Krug
# 228  Torey Krug
# 229  Torey Krug
# 230  Torey Krug
# 231  Torey Krug
# 232  Torey Krug
# 233  Torey Krug
# 234  Torey Krug
# 235  Torey Krug

# %%
# Tye Kartye
extracted_shift_data[extracted_shift_data['full_name']=="Tye Kartye"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 723             1       1             2:07           2:57    00:50   NaN
# 724             2       1             5:05           6:10    01:05   NaN
# 725             3       1            11:55          12:11    00:16   NaN
# 726             4       1            13:58          14:55    00:57   NaN
# 727             5       2             2:46           3:15    00:29   NaN
# 728             6       2             6:18           7:17    00:59   NaN
# 729             7       2            13:29          14:09    00:40   NaN
# 730             8       3             2:37           3:37    01:00   NaN
# 731             9       3            12:12          12:25    00:13   NaN
# 732            10       3            14:11          14:30    00:19   NaN
# 733            11       3            17:08          18:01    00:53   NaN
#
#       full_name
# 723  Tye Kartye
# 724  Tye Kartye
# 725  Tye Kartye
# 726  Tye Kartye
# 727  Tye Kartye
# 728  Tye Kartye
# 729  Tye Kartye
# 730  Tye Kartye
# 731  Tye Kartye
# 732  Tye Kartye
# 733  Tye Kartye

# %%
# Joey Daccord
extracted_shift_data[extracted_shift_data['full_name']=="Joey Daccord"][['shift_number','period','shift_start_time','shift_end_time','duration','Event','full_name']] # Passed
# Out:
#      shift_number  period shift_start_time shift_end_time duration Event  \
# 680             1       1             0:00          20:00    20:00     P
# 681             2       2             0:00          20:00    20:00    GP
# 682             3       3             0:00          20:00    20:00     P
# 683             4       4             0:00           5:00    05:00   NaN
#
#         full_name
# 680  Joey Daccord
# 681  Joey Daccord
# 682  Joey Daccord
# 683  Joey Daccord

# %% [markdown]
# Shift counts and shift times/durations match for each tested case.
#
# Test Case 1 Passed ✅

# %% [markdown]
# ### Test Case 2 - Compare Each Players All Sit, EV, PP, SH TOI
# Shifts for game 2023020028 can be found at https://www.nhl.com/scores/htmlreports/20232024/TV020028.HTM and https://www.nhl.com/scores/htmlreports/20232024/TH020028.HTM

# %%
# Read in linemate_data 
linemate_data = pd.read_csv("data/linemate-data-for-testing-2023020028.csv")
linemate_data
# Out:
#       Unnamed: 0 home_player_1_name  home_player_1_id home_player_1_position  \
# 0              0         Nick Leddy           8475181                      D
# 1              1         Nick Leddy           8475181                      D
# 2              2         Nick Leddy           8475181                      D
# 3              3         Nick Leddy           8475181                      D
# 4              4         Nick Leddy           8475181                      D
# ...          ...                ...               ...                    ...
# 3895        3895         Torey Krug           8476792                      D
# 3896        3896         Torey Krug           8476792                      D
# 3897        3897         Torey Krug           8476792                      D
# 3898        3898         Torey Krug           8476792                      D
# 3899        3899         Torey Krug           8476792                      D
#
#      home_player_2_name  home_player_2_id home_player_2_position  \
# 0        Colton Parayko           8476892                      D
# 1        Colton Parayko           8476892                      D
# 2        Colton Parayko           8476892                      D
# 3        Colton Parayko           8476892                      D
# 4        Colton Parayko           8476892                      D
# ...                 ...               ...                    ...
# 3895      Robert Thomas           8480023                      F
# 3896      Robert Thomas           8480023                      F
# 3897      Robert Thomas           8480023                      F
# 3898      Robert Thomas           8480023                      F
# 3899      Robert Thomas           8480023                      F
#
#      home_player_3_name  home_player_3_id home_player_3_position  ...  \
# 0         Robert Thomas           8480023                      F  ...
# 1         Robert Thomas           8480023                      F  ...
# 2         Robert Thomas           8480023                      F  ...
# 3         Robert Thomas           8480023                      F  ...
# 4         Robert Thomas           8480023                      F  ...
# ...                 ...               ...                    ...  ...
# 3895       Jordan Kyrou           8479385                      F  ...
# 3896       Jordan Kyrou           8479385                      F  ...
# 3897       Jordan Kyrou           8479385                      F  ...
# 3898       Jordan Kyrou           8479385                      F  ...
# 3899       Jordan Kyrou           8479385                      F  ...
#
#      strength_cat  home_player_7_name home_player_7_id home_player_7_position  \
# 0            even                 NaN              NaN                    NaN
# 1            even                 NaN              NaN                    NaN
# 2            even                 NaN              NaN                    NaN
# 3            even                 NaN              NaN                    NaN
# 4            even                 NaN              NaN                    NaN
# ...           ...                 ...              ...                    ...
# 3895         even                 NaN              NaN                    NaN
# 3896         even                 NaN              NaN                    NaN
# 3897         even                 NaN              NaN                    NaN
# 3898         even                 NaN              NaN                    NaN
# 3899         even                 NaN              NaN                    NaN
#
#       home_team away_team   game_date  game_season     game_id       game_type
# 0           STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 1           STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 2           STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 3           STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 4           STL       SEA  2023-10-14     20232024  2023020028  regular-season
# ...         ...       ...         ...          ...         ...             ...
# 3895        STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 3896        STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 3897        STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 3898        STL       SEA  2023-10-14     20232024  2023020028  regular-season
# 3899        STL       SEA  2023-10-14     20232024  2023020028  regular-season
#
# [3900 rows x 52 columns]

# %%
# Eeli Tolvanaen
all_toi = extract_toi("Eeli Tolvanen","away","all")
ev_toi = extract_toi("Eeli Tolvanen","away","even")
pp_toi = extract_toi("Eeli Tolvanen","away","away_advantage")
sh_toi = extract_toi("Eeli Tolvanen","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 13.216666666666667 EV: 12.55 PP: 0.6666666666666666 SH: 0.0

# %%
# Vince Dunn
all_toi = extract_toi("Vince Dunn","away","all")
ev_toi = extract_toi("Vince Dunn","away","even")
pp_toi = extract_toi("Vince Dunn","away","away_advantage")
sh_toi = extract_toi("Vince Dunn","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 24.166666666666668 EV: 23.25 PP: 0.9166666666666666 SH: 0.0

# %%
# Adam Larsson
all_toi = extract_toi("Adam Larsson","away","all")
ev_toi = extract_toi("Adam Larsson","away","even")
pp_toi = extract_toi("Adam Larsson","away","away_advantage")
sh_toi = extract_toi("Adam Larsson","away","home_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
'''
This is the test case I wanted to really test for this game. 
Larsson has 4:46 of SH TOI on the html shifts report
but over 5 here, and thats because he was on the ice while
STL had too many men on the ice for 6 seconds. The differecne
is exactly what we expect

I will keep this in and it is not a defect, just like for when a goalie is pulled
'''
# Out:
# All: 29.866666666666667 EV: 24.833333333333332 PP: 0.0 SH: 5.033333333333333
# '\nThis is the test case I wanted to really test for this game. \nLarsson has 4:46 of SH TOI on the html shifts report\nbut over 5 here, and thats because he was on the ice while\nSTL had too many men on the ice for 6 seconds. The differecne\nis exactly what we expect\n\nI will keep this in and it is not a defect, just like for when a goalie is pulled\n'

# %%
# Kasperi Kapanen
all_toi = extract_toi("Kasperi Kapanen","home","all")
ev_toi = extract_toi("Kasperi Kapanen","home","even")
pp_toi = extract_toi("Kasperi Kapanen","home","home_advantage")
sh_toi = extract_toi("Kasperi Kapanen","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi)
# Out:
# All: 17.883333333333333 EV: 14.583333333333334 PP: 2.15 SH: 1.15

# %%
# Pavel Buchnevich
all_toi = extract_toi("Pavel Buchnevich","home","all")
ev_toi = extract_toi("Pavel Buchnevich","home","even")
pp_toi = extract_toi("Pavel Buchnevich","home","home_advantage")
sh_toi = extract_toi("Pavel Buchnevich","home","away_advantage")
print("All:",all_toi,"EV:",ev_toi,"PP:",pp_toi,"SH:",sh_toi) # off by 1 second
# Out:
# All: 5.45 EV: 3.5166666666666666 PP: 1.9333333333333333 SH: 0.0

# %% [markdown]
# Player TOI's and the time differences match when they are expected to
#
# Test Case 2 Passed ✅

# %% [markdown]
# ### Test Case 3 - Compare html PBP On-Ice for Events to linemate_data Data Frame
# Should show the same players on ice at each even. PBP data can be found at https://www.nhl.com/scores/htmlreports/20232024/PL020028.HTM

# %%
# Hit at 1:03 of the 1st period
linemate_data[linemate_data['second']==63][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#    home_player_1_name home_player_2_name home_player_3_name  \
# 62         Torey Krug       Justin Faulk     Brayden Schenn
#
#    home_player_4_name home_player_5_name home_player_6_name  \
# 62       Brandon Saad    Kasperi Kapanen  Jordan Binnington
#
#    away_player_1_name away_player_2_name away_player_3_name  \
# 62        Will Borgen     Jamie Oleksiak     Jaden Schwartz
#
#    away_player_4_name away_player_5_name away_player_6_name
# 62      Alex Wennberg   Andre Burakovsky       Joey Daccord

# %%
# Goal at :40 of the 2nd period
linemate_data[linemate_data['second']==1240][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#      home_player_1_name home_player_2_name home_player_3_name  \
# 1239         Nick Leddy     Colton Parayko    Kasperi Kapanen
#
#      home_player_4_name home_player_5_name home_player_6_name  \
# 1239    Oskar Sundqvist  Jordan Binnington                NaN
#
#      away_player_1_name away_player_2_name away_player_3_name  \
# 1239         Vince Dunn     Jaden Schwartz      Eeli Tolvanen
#
#       away_player_4_name away_player_5_name away_player_6_name
# 1239  Oliver Bjorkstrand    Kailer Yamamoto       Joey Daccord

# %%
# Shot at :26 of the 3rd period
linemate_data[linemate_data['second']==2426][['home_player_1_name','home_player_2_name','home_player_3_name','home_player_4_name','home_player_5_name','home_player_6_name',
                                             'away_player_1_name','away_player_2_name','away_player_3_name','away_player_4_name','away_player_5_name','away_player_6_name']] # Exact match
# Out:
#      home_player_1_name home_player_2_name home_player_3_name  \
# 2425         Nick Leddy     Colton Parayko      Robert Thomas
#
#      home_player_4_name home_player_5_name home_player_6_name  \
# 2425       Brandon Saad       Jordan Kyrou  Jordan Binnington
#
#      away_player_1_name away_player_2_name away_player_3_name  \
# 2425       Adam Larsson         Vince Dunn      Jordan Eberle
#
#      away_player_4_name away_player_5_name away_player_6_name
# 2425      Matty Beniers       Jared McCann       Joey Daccord

# %% [markdown]
# On-Ice players match exactly for test cases
#
# Test Case 3 Passed ✅

# %% [markdown]
# ### Test Case 4 - Ensure Forward Line and Defensive Pair 5v5 TOI is Correct
# Manually loop through to make sure the function to calculate forward and defensemen line toi works

# %%
# Read in forward 5v5 report DF
forward_5v5 = pd.read_csv("data/5v5-forward-report-for-testing-2023020028.csv").head(10)
forward_5v5
# Out:
#    Unnamed: 0          forward_line_id            forward_1_name  \
# 0           0  8474586-8477955-8482665             Jordan Eberle
# 1           1  8475768-8477444-8477505            Jaden Schwartz
# 2           2  8476438-8479385-8480023             Robert Thomas
# 3           3  8476826-8477416-8480009             Eeli Tolvanen
# 4           4  8476897-8480281-8482089        Alexey Toropchenko
# 5           5  8475763-8477944-8478104               Kevin Hayes
# 6           6  8477930-8479977-8481789  Pierre-Edouard Bellemare
# 7           7  8475170-8477953-8480281            Brayden Schenn
# 8           8  8477402-8479385-8480023             Robert Thomas
# 9           9  8475170-8476438-8477953            Brayden Schenn
#
#    forward_1_id      forward_2_name  forward_2_id    forward_3_name  \
# 0       8474586       Matty Beniers       8482665      Jared McCann
# 1       8475768       Alex Wennberg       8477505  Andre Burakovsky
# 2       8480023        Brandon Saad       8476438      Jordan Kyrou
# 3       8480009  Oliver Bjorkstrand       8477416      Yanni Gourde
# 4       8480281     Jake Neighbours       8482089   Oskar Sundqvist
# 5       8475763         Jakub Vrana       8477944       Sammy Blais
# 6       8477930          Tye Kartye       8481789   Kailer Yamamoto
# 7       8475170  Alexey Toropchenko       8480281   Kasperi Kapanen
# 8       8480023        Jordan Kyrou       8479385  Pavel Buchnevich
# 9       8475170        Brandon Saad       8476438   Kasperi Kapanen
#
#    forward_3_id  toi_secs   toi_mins team        date    season     game_id  \
# 0     8477955.0       708  11.800000  SEA  2023-10-14  20232024  2023020028
# 1     8477444.0       703  11.716667  SEA  2023-10-14  20232024  2023020028
# 2     8479385.0       589   9.816667  STL  2023-10-14  20232024  2023020028
# 3     8476826.0       584   9.733333  SEA  2023-10-14  20232024  2023020028
# 4     8476897.0       481   8.016667  STL  2023-10-14  20232024  2023020028
# 5     8478104.0       445   7.416667  STL  2023-10-14  20232024  2023020028
# 6     8479977.0       386   6.433333  SEA  2023-10-14  20232024  2023020028
# 7     8477953.0       245   4.083333  STL  2023-10-14  20232024  2023020028
# 8     8477402.0       198   3.300000  STL  2023-10-14  20232024  2023020028
# 9     8477953.0       184   3.066667  STL  2023-10-14  20232024  2023020028
#
#         game_type
# 0  regular-season
# 1  regular-season
# 2  regular-season
# 3  regular-season
# 4  regular-season
# 5  regular-season
# 6  regular-season
# 7  regular-season
# 8  regular-season
# 9  regular-season

# %%
# For the top 5 most common lines in the game, lookup how maany 5v5 mins they played together through the linemate_data df. If they  match exactly, our function to build forward line toi reports works perfectly
for line in forward_5v5['forward_line_id'].tolist():
    p1 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_1_name']
    p2 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_2_name']
    p3 = forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['forward_3_name']
    print(p1,p2,p3)
    if forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['team']=="STL":
        print("Manual Calculation TOI:",calculate_forward_line_toi(p1,p2,p3,'home')," - Linemate Report TOI:",forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['toi_mins'])
    else:
        print("Manual Calculation TOI:",calculate_forward_line_toi(p1,p2,p3,'away')," - Linemate Report TOI:",forward_5v5[forward_5v5['forward_line_id']==line].iloc[0]['toi_mins'])
    print()
# Looks good. Lets do defenders now
# Out:
# Jordan Eberle Matty Beniers Jared McCann
# Manual Calculation TOI: 11.8  - Linemate Report TOI: 11.8
#
# Jaden Schwartz Alex Wennberg Andre Burakovsky
# Manual Calculation TOI: 11.716666666666667  - Linemate Report TOI: 11.716666666666669
#
# Robert Thomas Brandon Saad Jordan Kyrou
# Manual Calculation TOI: 9.816666666666666  - Linemate Report TOI: 9.816666666666666
#
# Eeli Tolvanen Oliver Bjorkstrand Yanni Gourde
# Manual Calculation TOI: 9.733333333333333  - Linemate Report TOI: 9.733333333333333
#
# Alexey Toropchenko Jake Neighbours Oskar Sundqvist
# Manual Calculation TOI: 8.016666666666667  - Linemate Report TOI: 8.016666666666667
#
# Kevin Hayes Jakub Vrana Sammy Blais
# Manual Calculation TOI: 7.416666666666667  - Linemate Report TOI: 7.416666666666667
#
# Pierre-Edouard Bellemare Tye Kartye Kailer Yamamoto
# Manual Calculation TOI: 6.433333333333334  - Linemate Report TOI: 6.433333333333334
#
# Brayden Schenn Alexey Toropchenko Kasperi Kapanen
# Manual Calculation TOI: 4.083333333333333  - Linemate Report TOI: 4.083333333333333
#
# Robert Thomas Jordan Kyrou Pavel Buchnevich
# Manual Calculation TOI: 3.3  - Linemate Report TOI: 3.3
#
# Brayden Schenn Brandon Saad Kasperi Kapanen
# Manual Calculation TOI: 3.066666666666667  - Linemate Report TOI: 3.066666666666667

# %%
# Read in defender report
defender_5v5 = pd.read_csv("data/5v5-defender-report-for-testing-2023020028.csv").head(10)
defender_5v5
# Out:
#    Unnamed: 0 defensemen_pair_id defensemen_1_name  defensemen_1_id  \
# 0           0    8476457-8478407      Adam Larsson          8476457
# 1           1    8475181-8476892        Nick Leddy          8475181
# 2           2    8475753-8476792        Torey Krug          8476792
# 3           3    8476467-8478840       Will Borgen          8478840
# 4           4    8474602-8475208    Justin Schultz          8474602
# 5           5    8474618-8481006   Marco Scandella          8474618
# 6           6    8476457-8478840       Will Borgen          8478840
# 7           7    8475753-8481006      Justin Faulk          8475753
# 8           8    8476467-8478407    Jamie Oleksiak          8476467
# 9           9    8476457-8476467      Adam Larsson          8476457
#
#   defensemen_2_name  defensemen_2_id  toi_secs   toi_mins team        date  \
# 0        Vince Dunn          8478407      1129  18.816667  SEA  2023-10-14
# 1    Colton Parayko          8476892      1127  18.783333  STL  2023-10-14
# 2      Justin Faulk          8475753       946  15.766667  STL  2023-10-14
# 3    Jamie Oleksiak          8476467       803  13.383333  SEA  2023-10-14
# 4    Brian Dumoulin          8475208       690  11.500000  SEA  2023-10-14
# 5      Tyler Tucker          8481006       505   8.416667  STL  2023-10-14
# 6      Adam Larsson          8476457       122   2.033333  SEA  2023-10-14
# 7      Tyler Tucker          8481006       104   1.733333  STL  2023-10-14
# 8        Vince Dunn          8478407        91   1.516667  SEA  2023-10-14
# 9    Jamie Oleksiak          8476467        77   1.283333  SEA  2023-10-14
#
#      season     game_id       game_type
# 0  20232024  2023020028  regular-season
# 1  20232024  2023020028  regular-season
# 2  20232024  2023020028  regular-season
# 3  20232024  2023020028  regular-season
# 4  20232024  2023020028  regular-season
# 5  20232024  2023020028  regular-season
# 6  20232024  2023020028  regular-season
# 7  20232024  2023020028  regular-season
# 8  20232024  2023020028  regular-season
# 9  20232024  2023020028  regular-season

# %%
# For the top 5 most common lines in the game, lookup how maany 5v5 mins they played together through the linemate_data df. If they  match exactly, our function to build forward line toi reports works perfectly
for pair in defender_5v5['defensemen_pair_id'].tolist():
    p1 = defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['defensemen_1_name']
    p2 = defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['defensemen_2_name']
    print(p1,p2)
    if defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['team']=="STL":
        print("Manual Calculation TOI:",calculate_defender_pair_toi(p1,p2,'home')," - Linemate Report TOI:",defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['toi_mins'])
    else:
        print("Manual Calculation TOI:",calculate_defender_pair_toi(p1,p2,'away')," - Linemate Report TOI:",defender_5v5[defender_5v5['defensemen_pair_id']==pair].iloc[0]['toi_mins'])
    print()
# Out:
# Adam Larsson Vince Dunn
# Manual Calculation TOI: 18.816666666666666  - Linemate Report TOI: 18.816666666666663
#
# Nick Leddy Colton Parayko
# Manual Calculation TOI: 18.783333333333335  - Linemate Report TOI: 18.78333333333333
#
# Torey Krug Justin Faulk
# Manual Calculation TOI: 15.766666666666667  - Linemate Report TOI: 15.766666666666667
#
# Will Borgen Jamie Oleksiak
# Manual Calculation TOI: 13.383333333333333  - Linemate Report TOI: 13.383333333333333
#
# Justin Schultz Brian Dumoulin
# Manual Calculation TOI: 11.5  - Linemate Report TOI: 11.5
#
# Marco Scandella Tyler Tucker
# Manual Calculation TOI: 8.416666666666666  - Linemate Report TOI: 8.416666666666666
#
# Will Borgen Adam Larsson
# Manual Calculation TOI: 2.033333333333333  - Linemate Report TOI: 2.033333333333333
#
# Justin Faulk Tyler Tucker
# Manual Calculation TOI: 1.7333333333333334  - Linemate Report TOI: 1.7333333333333334
#
# Jamie Oleksiak Vince Dunn
# Manual Calculation TOI: 1.5166666666666666  - Linemate Report TOI: 1.5166666666666666
#
# Adam Larsson Jamie Oleksiak
# Manual Calculation TOI: 1.2833333333333334  - Linemate Report TOI: 1.2833333333333334

# %% [markdown]
# 5v5 TOI's match perfectly
#
# Test Case 4 Passed ✅

# %% [markdown]
# #### Game 2023020017 Passed ✅

# %% [markdown]
# # ALL GAMES PASSED ✅
# Each game we tested presented a new scenario that the scraper will encounter if used throughout the whole season. I know it's only 3 games on this notebook, but I think this gives a good enough idea that this scraper works. With that being said, I encourage anyone who actually took this time to read this / anyone who uses the scraper to let me know if theres any other way you want me to test this, or if you find something wrong / concerning. I really would love feedback and any comments you may have
